# %%
import os
import datetime
import random
DEVICE_TYPES = ['Temperature_Sensor', 'Humidity_Sensor', 'Pressure_Sensor', 'Light_Sensor']
LOCATIONS = ['Lab1', 'Lab2', 'OfficeA', 'OfficeB', 'Warehouse']
READING_RANGES = {
    'Temperature_Sensor': (18.0, 30.0), # Celsius
    'Humidity_Sensor': (30.0, 80.0),   # Percentage
    'Pressure_Sensor': (980.0, 1030.0),# hPa
    'Light_Sensor': (100, 1000)        # Lux
}
raw_sensor_data = []

start_time = datetime.datetime.now()

for i in range(100):
    device_type = random.choice(DEVICE_TYPES)
    location = random.choice(LOCATIONS)

    min_value, max_value = READING_RANGES[device_type]
    value = round(random.uniform(min_value, max_value), 2)

    timestamp = (start_time + datetime.timedelta(minutes=i)).strftime("%Y-%m-%d %H:%M:%S")

    device_id = f"DEV{i+1:03d}"

    reading = (
        timestamp,
        device_id,
        device_type,
        location,
        value
    )

    raw_sensor_data.append(reading)

print("First 5 Sensor Readings:")
for reading in raw_sensor_data[:5]:
    print(reading)
# Out:
# First 5 Sensor Readings:
# ('2026-08-07 06:58:31', 'DEV001', 'Humidity_Sensor', 'Lab1', 47.01)
# ('2026-08-07 06:59:31', 'DEV002', 'Light_Sensor', 'Warehouse', 304.0)
# ('2026-08-07 07:00:31', 'DEV003', 'Pressure_Sensor', 'OfficeA', 1001.87)
# ('2026-08-07 07:01:31', 'DEV004', 'Pressure_Sensor', 'Lab2', 996.31)
# ('2026-08-07 07:02:31', 'DEV005', 'Humidity_Sensor', 'Warehouse', 73.95)

# %%
import os


report_filename = os.path.join(reports_dir, 'temperature_report.txt')
try:
    with open(report_filename, 'w') as f:
        for reading_dict in temperature_readings:
            line = generate_report_line(reading_dict)
            f.write(line + '\n')
    print(f"\nTemperature report written to '{report_filename}'.")
except IOError as e:
    print(f"\nError writing file '{report_filename}': {e}")
# Out:
# Temperature report written to 'sensor_reports/temperature_report.txt'.

# %%
import os
import datetime
import random
DEVICE_TYPES = ['Temperature_Sensor', 'Humidity_Sensor', 'Pressure_Sensor', 'Light_Sensor']
LOCATIONS = ['Lab1', 'Lab2', 'OfficeA', 'OfficeB', 'Warehouse']
READING_RANGES = {
    'Temperature_Sensor': (18.0, 30.0), # Celsius
    'Humidity_Sensor': (30.0, 80.0),   # Percentage
    'Pressure_Sensor': (980.0, 1030.0),# hPa
    'Light_Sensor': (100, 1000)        # Lux
}
temperature_readings = []

for reading in raw_sensor_data:
    if reading[2] == "Temperature_Sensor":
        temp_dict = {
            "timestamp": reading[0],
            "device_id": reading[1],
            "location": reading[3],
            "temperature_celsius": reading[4]
        }
        temperature_readings.append(temp_dict)

print("Temperature Readings:")
for reading in temperature_readings[:5]:
    print(reading)
# Out:
# Temperature Readings:
# {'timestamp': '2026-08-07 07:11:31', 'device_id': 'DEV014', 'location': 'OfficeA', 'temperature_celsius': 23.51}
# {'timestamp': '2026-08-07 07:14:31', 'device_id': 'DEV017', 'location': 'Lab2', 'temperature_celsius': 24.23}
# {'timestamp': '2026-08-07 07:20:31', 'device_id': 'DEV023', 'location': 'Lab1', 'temperature_celsius': 22.97}
# {'timestamp': '2026-08-07 07:24:31', 'device_id': 'DEV027', 'location': 'Lab2', 'temperature_celsius': 28.85}
# {'timestamp': '2026-08-07 07:25:31', 'device_id': 'DEV028', 'location': 'Lab2', 'temperature_celsius': 27.4}

# %%
import os
import datetime
import random
DEVICE_TYPES = ['Temperature_Sensor', 'Humidity_Sensor', 'Pressure_Sensor', 'Light_Sensor']
LOCATIONS = ['Lab1', 'Lab2', 'OfficeA', 'OfficeB', 'Warehouse']
READING_RANGES = {
    'Temperature_Sensor': (18.0, 30.0), # Celsius
    'Humidity_Sensor': (30.0, 80.0),   # Percentage
    'Pressure_Sensor': (980.0, 1030.0),# hPa
    'Light_Sensor': (100, 1000)        # Lux
}
unique_locations = set()

for reading in raw_sensor_data:
    unique_locations.add(reading[3])

print("Unique Locations:")
print(unique_locations)
# Out:
# Unique Locations:
# {'OfficeA', 'Warehouse', 'OfficeB', 'Lab1', 'Lab2'}

# %%
import os
import datetime
import random
DEVICE_TYPES = ['Temperature_Sensor', 'Humidity_Sensor', 'Pressure_Sensor', 'Light_Sensor']
LOCATIONS = ['Lab1', 'Lab2', 'OfficeA', 'OfficeB', 'Warehouse']
READING_RANGES = {
    'Temperature_Sensor': (18.0, 30.0), # Celsius
    'Humidity_Sensor': (30.0, 80.0), # Percentage
    'Pressure_Sensor': (980.0, 1030.0),# hPa
    'Light_Sensor': (100, 1000) # Lux
}
device_stats = {}

# Initialize the dictionary
for device in DEVICE_TYPES:
    device_stats[device] = (float('inf'), float('-inf'))

# Find minimum and maximum values for each device type
for reading in raw_sensor_data:
    device_type = reading[2]
    value = reading[4]

    min_value, max_value = device_stats[device_type]

    if value < min_value:
        min_value = value

    if value > max_value:
        max_value = value

    device_stats[device_type] = (min_value, max_value)

print("Device Statistics:")
for device, stats in device_stats.items():
    print(f"{device}: Min = {stats[0]}, Max = {stats[1]}")
# Out:
# Device Statistics:
# Temperature_Sensor: Min = 18.13, Max = 29.86
# Humidity_Sensor: Min = 33.44, Max = 76.09
# Pressure_Sensor: Min = 983.98, Max = 1023.05
# Light_Sensor: Min = 118.91, Max = 951.11

# %%
import os
import datetime
import random
DEVICE_TYPES = ['Temperature_Sensor', 'Humidity_Sensor', 'Pressure_Sensor', 'Light_Sensor']
LOCATIONS = ['Lab1', 'Lab2', 'OfficeA', 'OfficeB', 'Warehouse']
READING_RANGES = {
    'Temperature_Sensor': (18.0, 30.0), # Celsius
    'Humidity_Sensor': (30.0, 80.0), # Percentage
    'Pressure_Sensor': (980.0, 1030.0),# hPa
    'Light_Sensor': (100, 1000) # Lux
}
# Extract elements from the 10th to the 20th (inclusive)
sliced_readings_1 = raw_sensor_data[9:20]

# Extract every 5th reading starting from the beginning
sliced_readings_2 = raw_sensor_data[::5]

print("Readings from 10th to 20th:")
for reading in sliced_readings_1:
    print(reading)

print("\nEvery 5th Reading:")
for reading in sliced_readings_2:
    print(reading)
# Out:
# Readings from 10th to 20th:
# ('2026-08-07 07:07:31', 'DEV010', 'Light_Sensor', 'Warehouse', 673.99)
# ('2026-08-07 07:08:31', 'DEV011', 'Humidity_Sensor', 'Warehouse', 63.65)
# ('2026-08-07 07:09:31', 'DEV012', 'Light_Sensor', 'Warehouse', 269.48)
# ('2026-08-07 07:10:31', 'DEV013', 'Humidity_Sensor', 'Lab1', 55.9)
# ('2026-08-07 07:11:31', 'DEV014', 'Temperature_Sensor', 'OfficeA', 23.51)
# ('2026-08-07 07:12:31', 'DEV015', 'Light_Sensor', 'OfficeA', 907.92)
# ('2026-08-07 07:13:31', 'DEV016', 'Light_Sensor', 'Lab2', 667.91)
# ('2026-08-07 07:14:31', 'DEV017', 'Temperature_Sensor', 'Lab2', 24.23)
# ('2026-08-07 07:15:31', 'DEV018', 'Humidity_Sensor', 'OfficeA', 70.31)
# ('2026-08-07 07:16:31', 'DEV019', 'Pressure_Sensor', 'Warehouse', 1014.03)
# ('2026-08-07 07:17:31', 'DEV020', 'Light_Sensor', 'Lab2', 898.06)
#
# Every 5th Reading:
# ('2026-08-07 06:58:31', 'DEV001', 'Humidity_Sensor', 'Lab1', 47.01)
# ('2026-08-07 07:03:31', 'DEV006', 'Pressure_Sensor', 'OfficeB', 988.53)
# ('2026-08-07 07:08:31', 'DEV011', 'Humidity_Sensor', 'Warehouse', 63.65)
# ('2026-08-07 07:13:31', 'DEV016', 'Light_Sensor', 'Lab2', 667.91)
# ('2026-08-07 07:18:31', 'DEV021', 'Pressure_Sensor', 'Warehouse', 990.25)
# ('2026-08-07 07:23:31', 'DEV026', 'Pressure_Sensor', 'Lab2', 983.98)
# ('2026-08-07 07:28:31', 'DEV031', 'Pressure_Sensor', 'Warehouse', 997.28)
# ('2026-08-07 07:33:31', 'DEV036', 'Humidity_Sensor', 'Lab2', 38.65)
# ('2026-08-07 07:38:31', 'DEV041', 'Temperature_Sensor', 'OfficeB', 20.69)
# ('2026-08-07 07:43:31', 'DEV046', 'Temperature_Sensor', 'OfficeB', 28.74)
# ('2026-08-07 07:48:31', 'DEV051', 'Temperature_Sensor', 'Lab2', 24.16)
# ('2026-08-07 07:53:31', 'DEV056', 'Humidity_Sensor', 'OfficeB', 55.96)
# ('2026-08-07 07:58:31', 'DEV061', 'Temperature_Sensor', 'OfficeA', 19.95)
# ('2026-08-07 08:03:31', 'DEV066', 'Temperature_Sensor', 'Warehouse', 28.27)
# ('2026-08-07 08:08:31', 'DEV071', 'Humidity_Sensor', 'Lab2', 70.83)
# ('2026-08-07 08:13:31', 'DEV076', 'Humidity_Sensor', 'OfficeB', 33.44)
# ('2026-08-07 08:18:31', 'DEV081', 'Light_Sensor', 'OfficeB', 438.52)
# ('2026-08-07 08:23:31', 'DEV086', 'Light_Sensor', 'OfficeA', 915.55)
# ('2026-08-07 08:28:31', 'DEV091', 'Light_Sensor', 'Warehouse', 521.92)
# ('2026-08-07 08:33:31', 'DEV096', 'Light_Sensor', 'Lab1', 118.91)

# %%
import os
import datetime
import random
DEVICE_TYPES = ['Temperature_Sensor', 'Humidity_Sensor', 'Pressure_Sensor', 'Light_Sensor']
LOCATIONS = ['Lab1', 'Lab2', 'OfficeA', 'OfficeB', 'Warehouse']
READING_RANGES = {
    'Temperature_Sensor': (18.0, 30.0), # Celsius
    'Humidity_Sensor': (30.0, 80.0), # Percentage
    'Pressure_Sensor': (980.0, 1030.0),# hPa
    'Light_Sensor': (100, 1000) # Lux
}
# Task 1.5.3

# Access the device_type of the 5th reading
fifth_reading_device_type = raw_sensor_data[4][2]

# Extract the last 6 characters
device_type_suffix = fifth_reading_device_type[-6:]

print("5th Reading Device Type:", fifth_reading_device_type)
print("Device Type Suffix:", device_type_suffix)
# Out:
# 5th Reading Device Type: Humidity_Sensor
# Device Type Suffix: Sensor

# %%
import os
import datetime
import random
DEVICE_TYPES = ['Temperature_Sensor', 'Humidity_Sensor', 'Pressure_Sensor', 'Light_Sensor']
LOCATIONS = ['Lab1', 'Lab2', 'OfficeA', 'OfficeB', 'Warehouse']
READING_RANGES = {
    'Temperature_Sensor': (18.0, 30.0), # Celsius
    'Humidity_Sensor': (30.0, 80.0), # Percentage
    'Pressure_Sensor': (980.0, 1030.0),# hPa
    'Light_Sensor': (100, 1000) # Lux
}
def get_readings_by_location(readings_list, target_location):
    location_readings = []

    for reading in readings_list:
        if reading[3] == target_location:
            location_readings.append(reading)

    return location_readings
print(get_readings_by_location(raw_sensor_data, "Lab1"))
# Out:
# [('2026-08-07 06:58:31', 'DEV001', 'Humidity_Sensor', 'Lab1', 47.01), ('2026-08-07 07:10:31', 'DEV013', 'Humidity_Sensor', 'Lab1', 55.9), ('2026-08-07 07:20:31', 'DEV023', 'Temperature_Sensor', 'Lab1', 22.97), ('2026-08-07 07:21:31', 'DEV024', 'Humidity_Sensor', 'Lab1', 56.44), ('2026-08-07 07:26:31', 'DEV029', 'Temperature_Sensor', 'Lab1', 26.71), ('2026-08-07 07:35:31', 'DEV038', 'Humidity_Sensor', 'Lab1', 66.08), ('2026-08-07 07:37:31', 'DEV040', 'Pressure_Sensor', 'Lab1', 1010.54), ('2026-08-07 07:47:31', 'DEV050', 'Temperature_Sensor', 'Lab1', 28.85), ('2026-08-07 07:49:31', 'DEV052', 'Humidity_Sensor', 'Lab1', 76.09), ('2026-08-07 07:50:31', 'DEV053', 'Temperature_Sensor', 'Lab1', 29.38), ('2026-08-07 08:09:31', 'DEV072', 'Light_Sensor', 'Lab1', 673.44), ('2026-08-07 08:11:31', 'DEV074', 'Temperature_Sensor', 'Lab1', 27.77), ('2026-08-07 08:12:31', 'DEV075', 'Pressure_Sensor', 'Lab1', 999.85), ('2026-08-07 08:16:31', 'DEV079', 'Humidity_Sensor', 'Lab1', 35.76), ('2026-08-07 08:33:31', 'DEV096', 'Light_Sensor', 'Lab1', 118.91), ('2026-08-07 08:34:31', 'DEV097', 'Humidity_Sensor', 'Lab1', 51.27)]

# %%
sample_string="Programming Python"
substring_1 = sample_string[6:17]
substring_2 = sample_string[5::-1]

print("Substring 1:", substring_1)
print("Substring 2:", substring_2)
# Out:
# Substring 1: mming Pytho
# Substring 2: argorP

# %%
import os
import datetime
import random
DEVICE_TYPES = ['Temperature_Sensor', 'Humidity_Sensor', 'Pressure_Sensor', 'Light_Sensor']
LOCATIONS = ['Lab1', 'Lab2', 'OfficeA', 'OfficeB', 'Warehouse']
READING_RANGES = {
    'Temperature_Sensor': (18.0, 30.0), # Celsius
    'Humidity_Sensor': (30.0, 80.0), # Percentage
    'Pressure_Sensor': (980.0, 1030.0),# hPa
    'Light_Sensor': (100, 1000) # Lux
}
def calculate_average_temperature(temp_data_list):
    if len(temp_data_list) == 0:
        return 0.0

    total = 0

    for reading in temp_data_list:
        total += reading["temperature_celsius"]

    average = total / len(temp_data_list)
    return average;
print("Average Temperature:", calculate_average_temperature(temperature_readings))
# Out:
# Average Temperature: 25.68566666666667

# %%
import os
import datetime
import random
DEVICE_TYPES = ['Temperature_Sensor', 'Humidity_Sensor', 'Pressure_Sensor', 'Light_Sensor']
LOCATIONS = ['Lab1', 'Lab2', 'OfficeA', 'OfficeB', 'Warehouse']
READING_RANGES = {
    'Temperature_Sensor': (18.0, 30.0), # Celsius
    'Humidity_Sensor': (30.0, 80.0), # Percentage
    'Pressure_Sensor': (980.0, 1030.0),# hPa
    'Light_Sensor': (100, 1000) # Lux
}
def generate_report_line(reading_dict):
    return f"[{reading_dict['timestamp']}] Device {reading_dict['device_id']} at {reading_dict['location']}: {reading_dict['temperature_celsius']}°C"

# Example
if len(temperature_readings) > 0:
    print(generate_report_line(temperature_readings[0]))
# Out:
# [2026-08-07 07:11:31] Device DEV014 at OfficeA: 23.51°C

# %%
import os
import datetime
import random
DEVICE_TYPES = ['Temperature_Sensor', 'Humidity_Sensor', 'Pressure_Sensor', 'Light_Sensor']
LOCATIONS = ['Lab1', 'Lab2', 'OfficeA', 'OfficeB', 'Warehouse']
READING_RANGES = {
    'Temperature_Sensor': (18.0, 30.0), # Celsius
    'Humidity_Sensor': (30.0, 80.0), # Percentage
    'Pressure_Sensor': (980.0, 1030.0),# hPa
    'Light_Sensor': (100, 1000) # Lux
}
reports_dir = 'sensor_reports'

if not os.path.exists(reports_dir):
    os.makedirs(reports_dir)
    print(f"\nDirectory '{reports_dir}' created.")
else:
    print(f"\nDirectory '{reports_dir}' already exists.")
# Out:
# Directory 'sensor_reports' created.

# %%
import os
import datetime
import random
DEVICE_TYPES = ['Temperature_Sensor', 'Humidity_Sensor', 'Pressure_Sensor', 'Light_Sensor']
LOCATIONS = ['Lab1', 'Lab2', 'OfficeA', 'OfficeB', 'Warehouse']
READING_RANGES = {
    'Temperature_Sensor': (18.0, 30.0), # Celsius
    'Humidity_Sensor': (30.0, 80.0), # Percentage
    'Pressure_Sensor': (980.0, 1030.0),# hPa
    'Light_Sensor': (100, 1000) # Lux
}
if len(raw_sensor_data) > 1:
    first_timestamp_str = raw_sensor_data[0][0]
    last_timestamp_str = raw_sensor_data[-1][0]

    # Convert string to datetime object
    # The format string must exactly match the timestamp string
    date_format = '%Y-%m-%d %H:%M:%S'
    first_dt = datetime.datetime.strptime(first_timestamp_str, date_format)
    last_dt = datetime.datetime.strptime(last_timestamp_str, date_format)

    duration = last_dt - first_dt

    days = duration.days
    seconds = duration.total_seconds()
    hours = int(seconds // 3600) % 24  # Calculate remaining hours after full days
    minutes = int((seconds % 3600) // 60)  # Calculate remaining minutes after full hours

    print(f"\nDuration of data collection: {days} days, {hours} hours, {minutes} minutes.")
else:
    print("\nNot enough data to calculate duration.")
# Out:
# Duration of data collection: 0 days, 1 hours, 39 minutes.

# %%
import os
import random
random_values = []

for i in range(5):
    value = random.randint(100, 200)
    random_values.append(value)

print("\nRandom Values:")
print(random_values)
# Out:
# Random Values:
# [198, 200, 195, 127, 119]

# %%
import os
import datetime
import random
DEVICE_TYPES = ['Temperature_Sensor', 'Humidity_Sensor', 'Pressure_Sensor', 'Light_Sensor']
LOCATIONS = ['Lab1', 'Lab2', 'OfficeA', 'OfficeB', 'Warehouse']
READING_RANGES = {
    'Temperature_Sensor': (18.0, 30.0), # Celsius
    'Humidity_Sensor': (30.0, 80.0), # Percentage
    'Pressure_Sensor': (980.0, 1030.0),# hPa
    'Light_Sensor': (100, 1000) # Lux
}
report_filename = os.path.join(reports_dir, 'temperature_report.txt')

try:
    with open(report_filename, 'w') as f:
        for reading_dict in temperature_readings:
            line = generate_report_line(reading_dict)
            f.write(line + '\n')

    print(f"\nTemperature report written to '{report_filename}'.")
except IOError as e:
    print(f"\nError writing file '{report_filename}': {e}")
# Out:
# Temperature report written to 'sensor_reports/temperature_report.txt'.

# %%
import os
import datetime
import random
DEVICE_TYPES = ['Temperature_Sensor', 'Humidity_Sensor', 'Pressure_Sensor', 'Light_Sensor']
LOCATIONS = ['Lab1', 'Lab2', 'OfficeA', 'OfficeB', 'Warehouse']
READING_RANGES = {
    'Temperature_Sensor': (18.0, 30.0), # Celsius
    'Humidity_Sensor': (30.0, 80.0), # Percentage
    'Pressure_Sensor': (980.0, 1030.0),# hPa
    'Light_Sensor': (100, 1000) # Lux
}
read_report_lines = []

try:
    with open(report_filename, 'r') as f:
        read_report_lines = f.readlines()

    print("\nFirst 3 Lines of the Report:")

    for line in read_report_lines[:3]:
        print(line.strip())

except IOError as e:
    print(f"\nError reading file '{report_filename}': {e}")
# Out:
# First 3 Lines of the Report:
# [2026-08-07 07:11:31] Device DEV014 at OfficeA: 23.51°C
# [2026-08-07 07:14:31] Device DEV017 at Lab2: 24.23°C
# [2026-08-07 07:20:31] Device DEV023 at Lab1: 22.97°C

# %%
raw_sensor_data = [
    ['2026-08-07 10:00:00', 'Lab1', 'Temperature_Sensor', 25.5],
    ['2026-08-07 10:05:00', 'Lab2', 'Humidity_Sensor', 60.0],
    ['2026-08-07 10:10:00', 'OfficeA', 'Pressure_Sensor', 1005.0],
    ['2026-08-07 10:15:00', 'OfficeB', 'Light_Sensor', 500],
    ['2026-08-07 10:20:00', 'Warehouse', 'Temperature_Sensor', 27.0]
]
fifth_reading_device_type = raw_sensor_data[4][2]

device_type_suffix = fifth_reading_device_type[-6:]

print("5th Reading Device Type:", fifth_reading_device_type)
print("Device Type Suffix:", device_type_suffix)
# Out:
# 5th Reading Device Type: Temperature_Sensor
# Device Type Suffix: Sensor
